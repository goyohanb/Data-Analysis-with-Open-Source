# %% [markdown]
# <a href="https://colab.research.google.com/github/goyohanb/Data-Analysis-with-Open-Source/blob/main/%EC%98%A4%ED%94%88%EC%86%8C%EC%8A%A4_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D_5%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오픈소스 기반 데이터 분석 5강 - 데이터 저장

# %% [markdown]
# ## 5-1 CSV 형식 저장

# %%
#시작하기 전에 chapter 3에 있는 파일을
#왼쪽 폴더 클릭하고 옮겨둔 다음에 시작하기

import pandas as pd

data = {
    'student_id': [101, 102, 103, 104, 105],
    'database_score': [85, 76, 92, 63, 88],
    'cloudcomputing_score': [78, 82, 95, 70, 84],
    'python_score': [92, 78, 85, 75, 91],
    'watch_rate': [0.95, 0.87, 0.99, 0.80, 0.93]
}
## DataFrame 생성
df = pd.DataFrame(data)
df

## CSV 형식 저장
df.to_csv('student_analysis.csv', encoding='utf-8', index=False)
         #인덱스 012345를 안 보이게 하고 저장 -> index=False
         #저장된 파일은 왼쪽 파일 이모티콘 누르면 확인할 수 있음

# %% [markdown]
# ## 5-2 JSON 형식 저장

# %%
### 라이브러리 임포트
import json
import pandas as pd

data = {
    "이름": "홍길동",
    "나이": 25,
    "거주지": "서울",
    "관심사": ["프로그래밍", "데이터 분석", "여행"]
}

## json.dump를 이용한 저장
with open('output.json', mode='w', encoding='utf-8') as f:
    json.dump(data, f, indent=4, ensure_ascii=False)
     #indent 들여쓰기 4칸, 아스키코드를 False로 해서 한글로 저장


## DataFrame을 이용한 저장
df = pd.DataFrame([data])
# df = pd.DataFrame(data)
df.to_json('output_df.json', orient='records', indent=4, force_ascii=False)

# orient='records' 행 단위로 묶어서 저장
# orient='columns' 열 단위로 묶어서 저장.

# %% [markdown]
# ## 5-3 Pandas Dataframe 데이터 추출

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터학", "경영학", "농학", "교육학", "영어영문학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}
df = pd.DataFrame(data)
print(df)

## DataFrame 인덱스 출력
print(df.index) #RangeIndex(start=0, stop=5, step=1)

## DataFrame 컬럼 출력
print(df.columns)

## DataFrame 행 출력
print('###DataFrame 행 출력')
print(df.values.tolist()) # 파이썬의 리스트형태로 바뀜
print(df.values)

## DataFrame 값 출력
print(df.values.flatten())
  # 값들을 하나하나 쭉 나열할 때. 구조를 없애고 다 나열
# Out:
#     이름  학년   학점     학과    동아리
# 0  김철수   1  4.2   컴퓨터학  프로그래밍
# 1  이영희   2  3.8    경영학   독서토론
# 2  박민수   3  4.5     농학   로봇공학
# 3  최지훈   4  3.9    교육학   봉사활동
# 4  정소희   2  3.5  영어영문학   음악감상
# RangeIndex(start=0, stop=5, step=1)
# Index(['이름', '학년', '학점', '학과', '동아리'], dtype='object')
# ###DataFrame 행 출력
# [['김철수', 1, 4.2, '컴퓨터학', '프로그래밍'], ['이영희', 2, 3.8, '경영학', '독서토론'], ['박민수', 3, 4.5, '농학', '로봇공학'], ['최지훈', 4, 3.9, '교육학', '봉사활동'], ['정소희', 2, 3.5, '영어영문학', '음악감상']]
# [['김철수' 1 4.2 '컴퓨터학' '프로그래밍']
#  ['이영희' 2 3.8 '경영학' '독서토론']
#  ['박민수' 3 4.5 '농학' '로봇공학']
#  ['최지훈' 4 3.9 '교육학' '봉사활동']
#  ['정소희' 2 3.5 '영어영문학' '음악감상']]
# ['김철수' 1 4.2 '컴퓨터학' '프로그래밍' '이영희' 2 3.8 '경영학' '독서토론' '박민수' 3 4.5 '농학'
#  '로봇공학' '최지훈' 4 3.9 '교육학' '봉사활동' '정소희' 2 3.5 '영어영문학' '음악감상']

# %% [markdown]
# ## 5-4 DataFrame 생성 방법

# %%
import pandas as pd
import json

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

## 딕셔너리, csv, json으로 부터 DataFrame 생성
df1 = pd.DataFrame.from_dict(data)
df2 = pd.read_csv('students.csv') #챕터3 파일이 있어야함
df3 = pd.read_json('students.json')

## 세가지 방법 결과 비교  5행 5열
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (5, 5)
# (5, 5)
# (5, 5)

# %% [markdown]
# ## 5-5 DataFrame 저장 방법

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

## Dataframe 생성
pd = pd.DataFrame(data)


## CSV, JSON 형식으로 저장
df.to_csv('students_scores.csv')
df.to_json('students_scores.json')

## HTML 형식으로 저장
html_table = df.to_html()
with open('students_scores.html', 'w') as f:
    f.write(html_table)

print(html_table)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>이름</th>
#       <th>학년</th>
#       <th>학점</th>
#       <th>학과</th>
#       <th>동아리</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>김철수</td>
#       <td>1</td>
#       <td>4.2</td>
#       <td>컴퓨터학</td>
#       <td>프로그래밍</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>이영희</td>
#       <td>2</td>
#       <td>3.8</td>
#       <td>경영학</td>
#       <td>독서토론</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>박민수</td>
#       <td>3</td>
#       <td>4.5</td>
#       <td>농학</td>
#       <td>로봇공학</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>최지훈</td>
#       <td>4</td>
#       <td>3.9</td>
#       <td>교육학</td>
#       <td>봉사활동</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>정소희</td>
#       <td>2</td>
#       <td>3.5</td>
#       <td>영어영문학</td>
#       <td>음악감상</td>
#     </tr>
#   </tbody>
# ...

# %% [markdown]
# ## 5-6 실습 시나리오

# %% [markdown]
# ## 데이터 수집

# %%
import requests

url = "http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty"
api_key = '6bafd83cd117eb113a7c81fea77312de8a2a061809856c86f478aa8bc9121b56'

params = {
    'serviceKey': api_key,
    'returnType': 'json',
    'numOfRows': '100',
    'pageNo': '1',
    'sidoName': '서울',
    'ver': '1.0'
}

## 데이터 수집
response = requests.get(url, params=params)

## 호출 성공/실패 출력
print(response.json()) #자꾸 어떨 땐 잘 불러오는데 안 될 때도 있음. 코드 오류 없다.

#데이터프레임화 하기위해서는 받아온 데이터 구조를 파악할 필요가 있다.
#json 형식이고, items만 필요하니까 그 안에 있는 리스트만 가져와서 데이터 프레임으로 만든다.
# Out:
# {'response': {'body': {'totalCount': 40, 'items': [{'so2Grade': '1', 'coFlag': None, 'khaiValue': '69', 'so2Value': '0.002', 'coValue': '0.2', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '21', 'khaiGrade': '2', 'pm25Value': '11', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2026-09-20 16:00', 'coGrade': '1', 'no2Value': '0.005', 'stationName': '중구', 'pm10Grade': '1', 'o3Value': '0.052'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '63', 'so2Value': '0.002', 'coValue': '0.3', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '24', 'khaiGrade': '2', 'pm25Value': '8', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2026-09-20 16:00', 'coGrade': '1', 'no2Value': '0.013', 'stationName': '한강대로', 'pm10Grade': '1', 'o3Value': '0.045'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '67', 'so2Value': '0.002', 'coValue
# ...

# %% [markdown]
# ## 데이터 프레임 생성

# %%
import pandas as pd

## requests로부터 response, body, item 항목 읽기
data = response.json()['response']['body']['items']

print(type(data)) # 데이터 타입
print(len(data)) #데이터 길이
print(data[0]) # 첫 번째 데이터 출

df = pd.DataFrame(data) # 데이터 프레임
df

# df['pm25Grade']  #pm25Flag 컬럼값만 출력
# Out:
# <class 'list'>
# 40
# {'so2Grade': '1', 'coFlag': None, 'khaiValue': '69', 'so2Value': '0.002', 'coValue': '0.2', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '21', 'khaiGrade': '2', 'pm25Value': '11', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2026-09-20 16:00', 'coGrade': '1', 'no2Value': '0.005', 'stationName': '중구', 'pm10Grade': '1', 'o3Value': '0.052'}
#    so2Grade coFlag khaiValue so2Value coValue pm25Flag pm10Flag o3Grade  \
# 0         1   None        69    0.002     0.2     None     None       2
# 1         1   None        63    0.002     0.3     None     None       2
# 2         1   None        67    0.002     0.2     None     None       2
# 3         1   None        59    0.002     0.2     None     None       2
# 4         1   None        61    0.002     0.3     None     None       2
# 5         1   None        67    0.002     0.2     None     None       2
# ...

# %% [markdown]
# **굵은 텍스트**## 다양한 형식으로 데이터 저장

# %%
## CSV 형식 데이터 저장
df.to_csv('air_pollution.csv', index=False, encoding='utf-8')


## JSON 형식 데이터 저장
df.to_json('air_pollution.json', indent=4, force_ascii=False)
                                     # force_ascii=False 한글 잘 나오도록

## EXCEL 형식 데이터 저장
df.to_excel('air_pollution.xlsx', index=False)

## HTML 형식 데이터 저장
df.to_html('air_pollution.html')
